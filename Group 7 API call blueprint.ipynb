# %%
#Comment to force a push to remote

# %%
# Dependencies
import requests
import pandas as pd
import json

# %%
post_request_url = "https://api.chartmetric.com/api/token"
refresh_api_token = #Iykyk

# %%
post_results = requests.post(post_request_url, data = {"refreshtoken":refresh_api_token}, json=True)

# %%
print(post_results.text)

# %%
api_token = post_results.json()['token']

# %%
artist_id = 3957353
artist_url = f"https://api.chartmetric.com/api/artist/{artist_id}/career"

# %%
headers = {"Authorization": f"Bearer {api_token}"}

# %%
artist_results = requests.get(artist_url, headers = headers)

# %%
artist_results.json()
# Out:
# {'obj': [{'timestp': '2024-05-12',
#    'stage': 'superstar',
#    'stage_score': 18,
#    'momentum': 'growth',
#    'momentum_score': 67},
#   {'timestp': '2024-05-08',
#    'stage': 'superstar',
#    'stage_score': 18,
#    'momentum': 'growth',
#    'momentum_score': 69},
#   {'timestp': '2024-05-05',
#    'stage': 'superstar',
#    'stage_score': 17,
#    'momentum': 'growth',
#    'momentum_score': 72},
#   {'timestp': '2024-05-01',
#    'stage': 'superstar',
#    'stage_score': 17,
#    'momentum': 'growth',
#    'momentum_score': 74},
#   {'timestp': '2024-04-28',
#    'stage': 'superstar',
#    'stage_score': 17,
#    'momentum': 'growth',
#    'momentum_score': 76},
#   {'timestp': '2024-04-24',
#    'stage': 'superstar',
#    'stage_score': 17,
#    'momentum': 'growth',
#    'momentum_score': 77},
#   {'timestp': '2024-04-21',
#    'stage': 'superstar',
#    'stage_score': 17,
#    'momentum': 'growth',
#    'momentum_score': 78},
#   {'timestp': '2024-04-17',
#    'stage': 'superstar',
#    'stage_score': 17,
#    'momentum': 'growth',
#    'momentum_score': 78},
#   {'timestp': '2024-04-14',
#    'stage': 'superstar',
#    'stage_score': 16,
#    'momentum': 'growth',
#    'momentum_score': 78},
#   {'timestp': '2024-04-10',
#    'stage': 'superstar',
#    'stage_score': 16,
#    'momentum': 'growth',
#    'momentum_score': 77}]}

# %%
pd.json_normalize(artist_results.json()['obj'])
# Out:
#       timestp      stage  stage_score momentum  momentum_score
# 0  2024-05-12  superstar           18   growth              67
# 1  2024-05-08  superstar           18   growth              69
# 2  2024-05-05  superstar           17   growth              72
# 3  2024-05-01  superstar           17   growth              74
# 4  2024-04-28  superstar           17   growth              76
# 5  2024-04-24  superstar           17   growth              77
# 6  2024-04-21  superstar           17   growth              78
# 7  2024-04-17  superstar           17   growth              78
# 8  2024-04-14  superstar           16   growth              78
# 9  2024-04-10  superstar           16   growth              77

# %%
# FAN Metrics
source = 'tiktok'
fan_metrics_url = f'https://api.chartmetric.com/api/artist/{artist_id}/stat/{source}'

fan_metrics_results = requests.get(fan_metrics_url, headers=headers)

fan_metrics_results.json()
# Out:
# {'obj': {'link': 'https://www.tiktok.com/@tyla_',
#   'followers': [{'value': 8100000, 'timestp': '2024-04-22', 'diff': None},
#    {'value': 8200000, 'timestp': '2024-04-23', 'diff': 100000},
#    {'value': 8200000, 'timestp': '2024-04-24', 'diff': 0},
#    {'value': 8200000, 'timestp': '2024-04-25', 'diff': 0},
#    {'value': 8200000, 'timestp': '2024-04-26', 'diff': 0},
#    {'value': 8200000, 'timestp': '2024-04-27', 'diff': 0},
#    {'value': 8200000, 'timestp': '2024-04-28', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-04-29', 'diff': 100000},
#    {'value': 8300000, 'timestp': '2024-04-30', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-01', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-02', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-03', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-04', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-05', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-06', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-07', 'diff': 0},
#    {'value': 8300000, 'timestp': '2024-05-08', 'diff': 0},
#    {'value': 8400000, 'timestp': '2024-05-09', 'diff': 100000},
#    {'value': 8500000, 'timestp': '2024-05-10', 'diff': 100000},
#    {'value': 8600000, 'timestp': '2024-05-11', 'diff': 100000},
#    {'value': 8700000, 'timestp': '2024-05-12', 'diff': 100000}],
#   'likes': [{'value': 133400000, 'timestp': '2024-04-22', 'diff': None},
#    {'value': 134100000, 'timestp': '2024-04-23', 'diff': 700000},
#    {'value': 134400000, 'timestp': '2024-04-24', 'diff': 300000},
#    {'value': 134500000, 'timestp': '2024-04-25', 'diff': 100000},
#    {'value': 134700000, 'timestp': '2024-04-26', 'diff': 200000},
#    {'value': 134800000, 'timestp': '2024-04-27', 'diff': 100000},
#    {'value': 134900000, 'timestp': '2024-04-28', 'diff': 100000},
#    {'value': 134900000, 'timestp': '2024-04-29', 'diff': 0},
#    {'value': 135000000, 'timestp': '2024-04-30', 'diff': 100000},
#    {'value': 135100000, 'timestp': '2024-05-01', 'diff': 100000},
#    {'value': 135300000, 'timestp': '2024-05-02', 'diff': 200000},
#    {'value': 135300000, 'timestp': '2024-05-03', 'diff': 0},
#    {'value': 135400000, 'timestp': '2024-05-04', 'diff': 100000},
#    {'value': 135500000, 'timestp': '2024-05-05', 'diff': 100000},
#    {'value': 135500000, 'timestp': '2024-05-06', 'diff': 0},
#    {'value': 135600000, 'timestp': '2024-05-07', 'diff': 100000},
#    {'value': 135900000, 'timestp': '2024-05-08', 'diff': 300000},
#    {'value': 136600000, 'timestp': '2024-05-09', 'diff': 700000},
#    {'value': 137600000, 'timestp': '2024-05-10', 'diff': 1000000},
#    {'value': 138400000, 'timestp': '2024-05-11', 'diff': 800000},
#    {'value': 139200000, 'timestp': '2024-05-12', 'diff': 800000}]}}

# %%
link = fan_metrics_results.json()['obj']['link']
followers = pd.json_normalize(fan_metrics_results.json()['obj']['followers'])
likes = pd.json_normalize(fan_metrics_results.json()['obj']['likes'])

display(link)
display(followers)
display(likes)
# Out:
# 'https://www.tiktok.com/@tyla_'
#       value     timestp      diff
# 0   8100000  2024-04-22       NaN
# 1   8200000  2024-04-23  100000.0
# 2   8200000  2024-04-24       0.0
# 3   8200000  2024-04-25       0.0
# 4   8200000  2024-04-26       0.0
# 5   8200000  2024-04-27       0.0
# 6   8200000  2024-04-28       0.0
# 7   8300000  2024-04-29  100000.0
# 8   8300000  2024-04-30       0.0
# 9   8300000  2024-05-01       0.0
# 10  8300000  2024-05-02       0.0
# 11  8300000  2024-05-03       0.0
# 12  8300000  2024-05-04       0.0
# 13  8300000  2024-05-05       0.0
# 14  8300000  2024-05-06       0.0
# 15  8300000  2024-05-07       0.0
# 16  8300000  2024-05-08       0.0
# 17  8400000  2024-05-09  100000.0
# 18  8500000  2024-05-10  100000.0
# 19  8600000  2024-05-11  100000.0
# 20  8700000  2024-05-12  100000.0
#         value     timestp       diff
# 0   133400000  2024-04-22        NaN
# 1   134100000  2024-04-23   700000.0
# 2   134400000  2024-04-24   300000.0
# 3   134500000  2024-04-25   100000.0
# 4   134700000  2024-04-26   200000.0
# 5   134800000  2024-04-27   100000.0
# 6   134900000  2024-04-28   100000.0
# 7   134900000  2024-04-29        0.0
# 8   135000000  2024-04-30   100000.0
# 9   135100000  2024-05-01   100000.0
# 10  135300000  2024-05-02   200000.0
# 11  135300000  2024-05-03        0.0
# 12  135400000  2024-05-04   100000.0
# 13  135500000  2024-05-05   100000.0
# 14  135500000  2024-05-06        0.0
# 15  135600000  2024-05-07   100000.0
# 16  135900000  2024-05-08   300000.0
# 17  136600000  2024-05-09   700000.0
# 18  137600000  2024-05-10  1000000.0
# 19  138400000  2024-05-11   800000.0
# 20  139200000  2024-05-12   800000.0
